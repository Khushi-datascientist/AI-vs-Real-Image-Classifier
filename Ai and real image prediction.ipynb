# %% [markdown]
# # PREDICTING AI GENERATED IMAGE OR REAL IMAGE

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %% [markdown]
# ## Importing libraries

# %%
import tensorflow as tf
import os
import cv2
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import numpy as np
import keras

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
img = cv2.imread(os.path.join('data', 'FAKE', '1000 (2).jpg'))

# %%
#loading the imgaes from file directories(ai generated images)
import cv2
import os

# Full file path (use the absolute path to the image file)
file_path = r"C:\Users\finis\Downloads\archive_extracted\AiArtData\AiArtData\_portrait_of_a_stunning_Indian_v_95ff3e93-40ba-4dd8-90ed-d83729d37704-scaled.jpg"

# Load the image using OpenCV
img = cv2.imread(r"C:\Users\finis\Downloads\archive_extracted\AiArtData\AiArtData\_portrait_of_a_stunning_Indian_v_95ff3e93-40ba-4dd8-90ed-d83729d37704-scaled.jpg")

# Check if the image was loaded successfully
if img is None:
    print(f"Failed to load image from {r"C:\Users\finis\Downloads\archive_extracted\AiArtData\AiArtData\_portrait_of_a_stunning_Indian_v_95ff3e93-40ba-4dd8-90ed-d83729d37704-scaled.jpg"}. Please check the path and file.")
else:
    print("Image loaded successfully!")
# Out:
# Image loaded successfully!

# %%
#loading the imgaes from file directories(real images)
import cv2
import os

# Full file path (use the absolute path to the image file)
file_path = r"C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg"

# Load the image using OpenCV
img = cv2.imread(r"C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg")

# Check if the image was loaded successfully
if img is None:
    print(f"Failed to load image from {r"C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg"}. Please check the path and file.")
else:
    print("Image loaded successfully!")
# Out:
# Image loaded successfully!

# %%
#shape of real image
import cv2
img = cv2.imread(r"C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg")
print(img.shape)
# Out:
# (360, 360, 3)

# %%
#shaoe of ai generated images
import cv2
img = cv2.imread(r"C:\Users\finis\Downloads\archive_extracted\AiArtData\AiArtData\_portrait_of_a_stunning_Indian_v_95ff3e93-40ba-4dd8-90ed-d83729d37704-scaled.jpg")
print(img.shape)
# Out:
# (1435, 2560, 3)

# %%
import tensorflow as tf

# Load and process the first image
img_path1 = "C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg"
img1 = tf.keras.preprocessing.image.load_img(img_path1, target_size=(128, 128))

# Convert the first image to a numpy array
img_array1 = tf.keras.preprocessing.image.img_to_array(img1)

# Expand dimensions for the first image to make it batch-like
img_array1 = tf.expand_dims(img_array1, axis=0)

print(f"Shape of image 1: {img_array1.shape}")

# Load and process the second image
img_path2 = "C:/Users/finis/Downloads/archive_extracted/AiArtData/AiArtData/_portrait_of_a_stunning_Indian_v_95ff3e93-40ba-4dd8-90ed-d83729d37704-scaled.jpg"
img2 = tf.keras.preprocessing.image.load_img(img_path2, target_size=(128, 128))

# Convert the second image to a numpy array
img_array2 = tf.keras.preprocessing.image.img_to_array(img2)

# Expand dimensions for the second image to make it batch-like
img_array2 = tf.expand_dims(img_array2, axis=0)

print(f"Shape of image 2: {img_array2.shape}")
# Out:
# Shape of image 1: (1, 128, 128, 3)
# Shape of image 2: (1, 128, 128, 3)

# %%
import tensorflow as tf

# Path to the image file
image_path = "C:/Users/finis/Downloads/archive_extracted/AiArtData/AiArtData/_portrait_of_a_stunning_Indian_v_95ff3e93-40ba-4dd8-90ed-d83729d37704-scaled.jpg"

# Read the image file
image_data = tf.io.read_file(image_path)

# Decode the image as a JPEG
image = tf.image.decode_jpeg(image_data, channels=3)  # Assuming the image is RGB

# Optionally, resize the image if needed
image = tf.image.resize(image, [128, 128])  # Resize to 224x224, for example

# Convert to numpy if needed for further processing
image_numpy = image.numpy()

print(image_numpy.shape)
# Out:
# (128, 128, 3)

# %%
#matrix values of loaded ai generated images
dataset = tf.data.Dataset.from_tensor_slices([image_numpy])  # Create a dataset from a NumPy array
data_it = dataset.as_numpy_iterator()

for element in data_it:
    print(element)
# Out:
# [[[ 23.        12.         8.      ]
#   [ 26.789062  13.105469  10.      ]
#   [ 23.        12.         6.      ]
#   ...
#   [221.05273  232.94727  230.73633 ]
#   [206.02539  221.3418   224.44727 ]
#   [176.76172  200.91992  207.63086 ]]
#
#  [[ 19.        12.         4.      ]
#   [ 21.        12.         5.      ]
#   [ 22.        13.         6.      ]
#   ...
#   [217.1836   223.1836   219.5     ]
#   [162.23438  195.86719  202.55078 ]
#   [ 80.3418   112.5      132.5     ]]
#
#  [[ 14.472656  10.527344   6.      ]
#   [ 18.        13.         9.      ]
#   [ 23.        14.         7.      ]
#   ...
#   [197.6543   206.91797  206.44531 ]
#   [ 87.52734  119.52734  142.52734 ]
#   [ 79.5      111.5      134.5     ]]
#
#  ...
#
#  [[ 82.02734   49.027344  15.027344]
#   [ 97.5       59.        15.      ]
#   [108.5       66.5       16.5     ]
#   ...
#   [ 27.236328  29.        24.      ]
#   [ 30.236328  30.236328  29.763672]
#   [ 25.        27.        26.      ]]
#
# ...

# %%
import tensorflow as tf

# Path to the image file
image_path = "C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg" 

# Read the image file
image_data = tf.io.read_file(image_path)

# Decode the image as a JPEG
image = tf.image.decode_jpeg(image_data, channels=3)  # Assuming the image is RGB

# Optionally, resize the image if needed
image = tf.image.resize(image, [128, 128])  # Resize to 224x224, for example

# Convert to numpy if needed for further processing
image_numpy = image.numpy()

print(image_numpy.shape)
# Out:
# (128, 128, 3)

# %%
#matrix values of loaded real images
dataset = tf.data.Dataset.from_tensor_slices([image_numpy])  # Create a dataset from a NumPy array
data_it = dataset.as_numpy_iterator()

for element in data_it:
    print(element)
# Out:
# [[[112.049805 130.60352  114.603516]
#   [118.833984 142.41797  126.11035 ]
#   [126.83789  146.0127   131.875   ]
#   ...
#   [172.29297  162.15527  136.49902 ]
#   [163.66113  147.12988  117.541016]
#   [129.15234  105.78613   74.08496 ]]
#
#  [[105.4834   125.805664 114.149414]
#   [117.112305 133.6748   120.79785 ]
#   [125.006836 142.59375  128.42676 ]
#   ...
#   [170.97949  161.68066  132.83008 ]
#   [162.60449  148.07324  120.66699 ]
#   [133.69238  109.243164  78.384766]]
#
#  [[104.81738  122.04297  111.62402 ]
#   [114.77051  134.60742  121.46484 ]
#   [121.99609  139.62305  127.84277 ]
#   ...
#   [165.25195  155.31445  126.21875 ]
#   [163.05566  149.24316  119.63574 ]
#   [141.69336  115.59961   82.88086 ]]
#
#  ...
#
#  [[181.42188  169.36719  148.66797 ]
#   [182.62012  167.70703  148.62305 ]
#   [169.58008  157.41797  137.01074 ]
#   ...
#   [243.53125  243.75098  241.65625 ]
#   [245.9961   246.29492  244.14551 ]
#   [239.04297  239.41797  236.04395 ]]
#
# ...

# %%
img.shape
# Out:
# (360, 360, 3)

# %%
img = cv2.imread(os.path.join('data', 'FAKE', '1000 (2).jpg'))

# %%
import tensorflow as tf

# Path to the directory containing the image dataset
dataset_path = r"C:\Users\finis\Downloads\archive_extracted\AiArtData"

# Load the dataset from the specified directory
data = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    image_size=(32, 32),  # Resize images to 32x32
    batch_size=32  # Set batch size
)
# Out:
# Found 536 files belonging to 1 classes.

# %%
data_it = data.as_numpy_iterator()

# %%
batch = data_it.next()

# %%
import matplotlib.pyplot as plt  # Ensure matplotlib is imported

# Now the plotting code will work
fig, ax = plt.subplots(ncols=8, figsize=(16, 4))
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img.astype(int))
    ax[idx].set_title(batch[1][idx])  # Set the title to the label

# %%
import matplotlib.pyplot as plt  # Ensure matplotlib is imported

# Now the plotting code will work
fig, ax = plt.subplots(ncols=14, figsize=(25,7))
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img.astype(int))
    ax[idx].set_title(batch[1][idx])  # Set the title to the label
    ax[idx].axis('off')  # Hide the axis for cleaner look

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Mock data
# Create 8 random images of size 64x64 with 3 color channels
images = np.random.rand(8, 64, 64, 3)

# Create corresponding labels as plain text
labels = [f'Label {i+5}' for i in range(8)]  # Simple labels for each image

# Define batch variable
batch = (images, labels)

# Plotting code
fig, ax = plt.subplots(ncols=8, figsize=(16, 4))
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img)  # No need for `.astype(int)` as `imshow` can handle float
    ax[idx].set_title(batch[1][idx])  # Set the title to the label
    ax[idx].axis('off')  # Hide the axis for cleaner look

plt.tight_layout()
plt.show()

# %% [markdown]
# ## preprocessing

# %%
print(batch[0].min())
print(batch[0].max())
# Out:
# 0.0
# 255.0

# %%
 #scaling the3 data between 0 and 1
data= data.map(lambda x,y:(x/255,y))

# %%
scaled_it= data.as_numpy_iterator()

# %%
batch= scaled_it.next()

# %%
print(batch[0].min())
print(batch[0].max())
# Out:
# 0.0
# 1.0

# %% [markdown]
# ## splitting the data into traing,cross-validationn and testing

# %%
len(data)
# Out:
# 17

# %%
train_size = int(len(data)*0.7)
cv_size = int(len(data)*0.2)
test_size = int(len(data)*0.1)+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 train_size = int(len(data)*0.7)
#       2 cv_size = int(len(data)*0.2)
#       3 test_size = int(len(data)*0.1)+1
#
# NameError: name 'data' is not defined

# %%
train_size+cv_size+test_size
# Out:
# 16

# %%
train = data.take(train_size)
cv=data.skip(train_size).take(cv_size)
test = data.skip(train_size+cv_size).take(test_size)

# %%
len(train)+len(cv)+len(test)
# Out:
# 16

# %% [markdown]
# ## building the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D , MaxPooling2D , Dense, Flatten

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (4, 4), 1, activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (4, 4), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (4, 4), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\finis\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile('adam', loss = tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 29, 29, 16)          │             784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 32)          │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 32)            │               0 │
# ...

# %%
logdir = 'logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=cv, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.8137 - loss: 0.5394 - val_accuracy: 1.0000 - val_loss: 0.0210
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 223ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 6.4927e-06
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 1.0000 - loss: 1.4698e-06 - val_accuracy: 1.0000 - val_loss: 4.7606e-07
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 1.0000 - loss: 3.7706e-08 - val_accuracy: 1.0000 - val_loss: 1.2591e-07
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 1.0000 - loss: 2.2281e-09 - val_accuracy: 1.0000 - val_loss: 5.2235e-10
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 1.0000 - loss: 4.6459e-09 - val_accuracy: 1.0000 - val_loss: 1.5449e-09
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 1.0000 - loss: 1.1415e-08 - val_accuracy: 1.0000 - val_loss: 6.2917e-08
# Epoch 8/20
# ...

# %% [markdown]
# ## performance
# ## model evaluation

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='blue', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='cv_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='blue', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='cv_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
rec = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    rec.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
print(f'Precision: {pre.result().numpy()}, Recall: {rec.result().numpy()}, Accuracy: {acc.result().numpy()}')
# Out:
# Precision: 0.0, Recall: 0.0, Accuracy: 1.0

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('model','ai_imageclassifier.h5'))
model = load_model(os.path.join('model','ai_imageclassifier.h5'))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import matplotlib.pyplot as plt

# Corrected string with proper closing quote
img = cv2.imread('C:/Users/finis/Downloads/archive_extracted/AiArtData/AiArtData/_portrait_of_a_stunning_Indian_v_95ff3e93-40ba-4dd8-90ed-d83729d37704-scaled.jpg')

# Convert the image from BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img)
plt.show()

# %%
import os
from tensorflow.keras.models import load_model

# Define the model directory and filename
model_dir = 'model'
model_filename = 'real_imageclassifier.keras'

# Ensure the directory exists
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# Save the model in the Keras native format
model.save(os.path.join(model_dir, model_filename))

# Load the model
model = load_model(os.path.join(model_dir, model_filename))

# Optional: Print model summary to ensure it loaded correctly
model.summary()

# %%
y_pred = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step

# %%
y_pred
# Out:
# array([[5.2611593e-10]], dtype=float32)

# %%
# real vs ai images 
if y_pred > 0.5: 
    print(f'Predicted class: REAL IMAGE')
else:
    print(f'Predicted class: AI GENERATED')
# Out:
# Predicted class: AI GENERATED

# %%
#real images
import tensorflow as tf

# Path to the directory containing the image dataset
dataset_path = r"C:\Users\finis\Downloads\archive_extracted\RealArt"

# Load the dataset from the specified directory
data = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    image_size=(32, 32),  # Resize images to 32x32
    batch_size=32  # Set batch size
)
# Out:
# Found 435 files belonging to 1 classes.

# %%
data_it = data.as_numpy_iterator()

# %%
batch = data_it.next()

# %%
fig, ax = plt.subplots(ncols=8, figsize=(10, 10))
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
#Scaling the data between 0 and 1
print(batch[0].min())
print(batch[0].max())
# Out:
# 0.0
# 255.0

# %%
data = data.map(lambda x, y : (x/255, y))

# %%
scaled_it = data.as_numpy_iterator()

# %%
print(batch[0].min())
print(batch[0].max())
# Out:
# 0.0
# 255.0

# %%
#Splitting the data into training, cross-validation and testing sets

# %%
len(data)
# Out:
# 14

# %%
train_size = int(len(data)*0.7)
cv_size = int(len(data)*0.2)
test_size = int(len(data)*0.1)+1

# %%
train_size+cv_size+test_size
# Out:
# 13

# %%
train = data.take(train_size)
cv = data.skip(train_size).take(cv_size)
test = data.skip(train_size+cv_size).take(test_size)

# %%
len(train)+len(cv)+len(test)
# Out:
# 13

# %%
#building

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (4, 4), 1, activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (4, 4), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (4, 4), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss = tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 29, 29, 16)          │             784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 11, 11, 32)          │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 5, 5, 32)            │               0 │
# ...

# %%
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train, epochs=20, validation_data=cv, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - accuracy: 0.8254 - loss: 0.4923 - val_accuracy: 1.0000 - val_loss: 0.0292
# Epoch 2/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 414ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 1.1762e-04
# Epoch 3/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 438ms/step - accuracy: 1.0000 - loss: 5.9402e-05 - val_accuracy: 1.0000 - val_loss: 9.4935e-06
# Epoch 4/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 478ms/step - accuracy: 1.0000 - loss: 6.1991e-06 - val_accuracy: 1.0000 - val_loss: 3.0720e-08
# Epoch 5/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 443ms/step - accuracy: 1.0000 - loss: 1.0929e-06 - val_accuracy: 1.0000 - val_loss: 1.5071e-07
# Epoch 6/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 465ms/step - accuracy: 1.0000 - loss: 1.0353e-06 - val_accuracy: 1.0000 - val_loss: 1.7639e-07
# Epoch 7/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 554ms/step - accuracy: 1.0000 - loss: 3.4742e-07 - val_accuracy: 1.0000 - val_loss: 8.2334e-07
# Epoch 8/20
# ...

# %%
#performace and model evaluation 
fig = plt.figure()
plt.plot(hist.history['loss'], color='blue', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='cv_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='blue', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='cv_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
pre = Precision()
rec = Recall()
acc = BinaryAccuracy()
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    rec.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
print(f'Precision: {pre.result().numpy()}, Recall: {rec.result().numpy()}, Accuracy: {acc.result().numpy()}')
# Out:
# Precision: 0.0, Recall: 0.0, Accuracy: 1.0

# %%
from tensorflow.keras.models import load_model
model.save(os.path.join('model','real_imageclassifier.h5'))
model = load_model(os.path.join('model','real_imageclassifier.h5'))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import matplotlib.pyplot as plt

# Corrected string without the leading space
img = cv2.imread('C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg')

# Check if the image was loaded successfully
if img is None:
    print("Failed to load image.")
else:
    # Convert the image from BGR to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the image
    plt.imshow(img)
    plt.axis('off')  # Hide axes for a cleaner look
    plt.show()

# %%
import cv2
import numpy as np

# Assume original image is loaded
img = cv2.imread('C:/Users/finis/Downloads/archive_extracted/RealArt/RealArt/2ibwo5nyey_76768945_200ee080_6772_11ea_99f1_23346ee95a58.jpg')


# Resize to 64x64 (or the size your model expects)
resize = cv2.resize(img, (64, 64))

# %%
y_pred
# Out:
# array([[5.2611593e-10]], dtype=float32)

# %% [markdown]
# ## final prediction

# %%
#classiffy whether the loaded image is ai generated or real image 
if y_pred > 0.5: 
    print(f'Predicted class:  AI GENERATED IMAGE')
else:
    print(f'Predicted class: REAL IMAGE')
# Out:
# Predicted class: REAL IMAGE
